# %%
import random
from math import *
from operator import itemgetter
import numpy as np

# 读文件得到“用户-电影”数据
def get_dataset(filename, pivot=0.75):
    trainSet_len = 0
    testSet_len = 0
    
    trainSet = {}
    testSet = {}
    m_dic = {}
    
    for line in load_file(filename):
        user, movie, rating,timestamp  = line.split(',')
        if random.random() < pivot:
            trainSet.setdefault(user, {})
            trainSet[user][movie] = rating
            trainSet_len += 1
            m_dic.setdefault(movie,[])
            m_dic[movie].append(float(rating))
        else:
            testSet.setdefault(user, {})
            testSet[user][movie] = rating
            testSet_len += 1
    print('Split trainingSet and testSet success!')
    print('TrainSet = %s' % trainSet_len)
    print('TestSet = %s' % testSet_len)
    
    return trainSet, testSet, m_dic


# 读文件，返回文件的每一行
def load_file(filename):
    with open(filename, 'r') as f:
        for i, line in enumerate(f):
            if i == 0:  # 去掉文件第一行的title
                continue
            yield line.strip('\r\n')
    print('Load %s success!' % filename)


def getab(dic_u, dic_v):
    sim_movie = list(dic_u.keys()&dic_v.keys())
    a = []
    b = []
    for m in sim_movie:
        a.append(float(dic_u[m]))
        b.append(float(dic_v[m]))
    
    for k,v in dic_u.items():
        if k not in sim_movie:
            a.append(float(v))
            b.append(0)
    
    for k,v in dic_v.items():
        if k not in sim_movie:
            a.append(0)
            b.append(float(v))

    return a,b

def get_adj_ab(dic_u, dic_v, m_dic):
    sim_movie = list(dic_u.keys()&dic_v.keys())
    a = []
    b = []
    for m in sim_movie:
        num = sum(m_dic[m])/len(m_dic[m])
        a.append(float(dic_u[m])-num)
        b.append(float(dic_v[m])-num)
    
    for k,v in dic_u.items():
        if k not in sim_movie:
            num = sum(m_dic[k])/len(m_dic[k])
            a.append(float(v)-num)
            b.append(-num)
    
    for k,v in dic_v.items():
        if k not in sim_movie:
            num = sum(m_dic[k])/len(m_dic[k])
            a.append(-num)
            b.append(float(v)-num)
    return a,b

def eculidSim(x,y):
    return sqrt(sum(pow(a-b,2) for a,b in zip(x,y)))

def manhattan_dis(x,y):
    return sum(abs(a-b) for a,b in zip(x,y))

def cos_sim(x, y):

    x = np.mat(x)
    y = np.mat(y)
    num = float(x * y.T)
    denom = np.linalg.norm(x) * np.linalg.norm(y)
    sim = num / denom
    return sim

def jaccard_sim(x,y):
    intersection_cardonality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardonality/float(union_cardinality)

def pearson(vb,vc):
    return np.mean(np.multiply((vc-np.mean(vc)),(vb-np.mean(vb))))/(np.std(vb)*np.std(vc))


# 计算用户之间的相似度
def calc_user_sim(trainSet, method, m_dic):
    # 构建“电影-用户”倒排索引
    # key = movieID, value = list of userIDs who have seen this movie
    print('Building movie-user table ...')
    movie_user = {}
    
    user_sim_matrix = {}
    movie_count = 0
    
    for user, movies in trainSet.items():
        for movie in movies:
            if movie not in movie_user:
                movie_user[movie] = set()
            movie_user[movie].add(user)
    print('Build movie-user table success!')

    movie_count = len(movie_user)
    print('Total movie number = %d' % movie_count)

    print('Build user co-rated movies matrix ...')
    for movie, users in movie_user.items():
        for u in users:
            for v in users:
                if u == v:
                    continue
                user_sim_matrix.setdefault(u, {})
                user_sim_matrix[u].setdefault(v, 0)
                user_sim_matrix[u][v] += 1
    print('Build user co-rated movies matrix success!')


    if method == 'sim':
        ######      最基本的那种
        # 计算相似性
        print('Calculating user similarity matrix ...   原始方法')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                user_sim_matrix[u][v] = count / sqrt(len(trainSet[u]) * len(trainSet[v]))
        print('Calculate user similarity matrix success!')
        ######

    if method == 'eculidSim':
        ######  欧几里得距离
        print('Calculating user similarity matrix ...   欧几里得')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = getab(trainSet[u],trainSet[v])
                    user_sim_matrix[u][v] = eculidSim(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')
        ######
    
    if method == 'manhattan':
        print('Calculating user similarity matrix ...   曼哈顿')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = getab(trainSet[u],trainSet[v])
                    user_sim_matrix[u][v] = manhattan_dis(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')

    if method == 'jaccard':
        print('Calculating user similarity matrix ...   jaccard')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = getab(trainSet[u],trainSet[v])
                    user_sim_matrix[u][v] = jaccard_sim(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')

    if method == 'cosine':
        print('Calculating user similarity matrix ...   余弦')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = getab(trainSet[u],trainSet[v])
                    user_sim_matrix[u][v] = cos_sim(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')


    if method == 'pearson':
        print('Calculating user similarity matrix ...   皮尔逊')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = getab(trainSet[u],trainSet[v])
                    user_sim_matrix[u][v] = pearson(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')
    
    if method == 'adj_cosine':
        print('Calculating user similarity matrix ...   改进余弦')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = get_adj_ab(trainSet[u],trainSet[v], m_dic)
                    user_sim_matrix[u][v] = cos_sim(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')
    
    return user_sim_matrix, movie_count


# 针对目标用户U，找到其最相似的K个用户，产生N个推荐
def recommend(user, n_sim_user, n_rec_movie, trainSet, user_sim_matrix, m_dic):
    K = n_sim_user
    N = n_rec_movie
    rank = {}
    watched_movies = trainSet[user]

    # v=similar user, wuv=similar factor
    # print(user)
    xxx = sorted(user_sim_matrix[user].items(), key=itemgetter(1), reverse=True)[0:K]
    for v, wuv in xxx:
        for movie,value in trainSet[v].items():
            if movie in watched_movies:
                continue
            rank.setdefault(movie, 0)
            rank[movie] += wuv*float(value)
    return sorted(rank.items(), key=itemgetter(1), reverse=True)[0:N]


# 产生推荐并通过准确率、召回率和覆盖率进行评估
def evaluate(n_rec_movie, trainSet, user_sim_matrix, testSet, n_sim_user, movie_count):
    print("Evaluation start ...")
    N = n_rec_movie
    # 准确率和召回率
    hit = 0
    rec_count = 0
    test_count = 0
    # 覆盖率
    all_rec_movies = set()

    for i, user, in enumerate(trainSet):
        if user in user_sim_matrix:
            test_movies = testSet.get(user, {})
            rec_movies = recommend(user, n_sim_user, n_rec_movie, trainSet, user_sim_matrix, m_dic)
            for movie, w in rec_movies:
                if movie in test_movies:
                    hit += 1
                all_rec_movies.add(movie)
            rec_count += N
            test_count += len(test_movies)

    precision = hit / (1.0 * rec_count)
    recall = hit / (1.0 * test_count)
    coverage = len(all_rec_movies) / (1.0 * movie_count)
    print('precisioin=%.4f\trecall=%.4f\tcoverage=%.4f' % (precision, recall, coverage))


# trainSet, testSet = get_dataset(filename = 'ml/rating.csv', pivot=1)
# user_sim_matrix, movie_count = calc_user_sim(trainSet)
# n_sim_user = 10
# n_rec_movie = 20

trainSet, testSet, m_dic = get_dataset(filename = 'ratings.csv')
methods = ['sim', 'eculidSim', 'manhattan', 'jaccard', 'cosine', 'pearson']
for method in methods:
    user_sim_matrix, movie_count = calc_user_sim(trainSet, method, m_dic)
    for num in [1,5,8,10,20,30]: 
        n_sim_user = num
        n_rec_movie = 30
        print('最相似用户为{}个'.format(num))
        evaluate(n_rec_movie, trainSet, user_sim_matrix, testSet, n_sim_user, movie_count)
# Out:
# Load ratings.csv success!
# Split trainingSet and testSet success!
# TrainSet = 75418
# TestSet = 25418
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8709
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   原始方法
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.1082	recall=0.0779	coverage=0.2365
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.1850	recall=0.1332	coverage=0.1620
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.2014	recall=0.1450	coverage=0.1236
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.2075	recall=0.1494	coverage=0.1077
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.2169	recall=0.1562	coverage=0.0705
# 最相似用户为30个
# Evaluation start ...
# precisioin=0.2181	recall=0.1571	coverage=0.0547
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8709
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   欧几里得
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.0522	recall=0.0376	coverage=0.0185
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.0799	recall=0.0576	coverage=0.0258
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.0899	recall=0.0648	coverage=0.0235
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.0913	recall=0.0657	coverage=0.0212
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.1038	recall=0.0747	coverage=0.0192
# 最相似用户为30个
# Evaluation start ...
# precisioin=0.1066	recall=0.0768	coverage=0.0192
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8709
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   曼哈顿
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.0528	recall=0.0380	coverage=0.0122
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.0799	recall=0.0576	coverage=0.0211
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.0895	recall=0.0644	coverage=0.0216
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.0942	recall=0.0678	coverage=0.0214
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.1101	recall=0.0792	coverage=0.0183
# 最相似用户为30个
# Evaluation start ...
# precisioin=0.1107	recall=0.0797	coverage=0.0186
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8709
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   jaccard
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.0685	recall=0.0493	coverage=0.1927
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.1138	recall=0.0819	coverage=0.1152
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.1250	recall=0.0900	coverage=0.0847
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.1306	recall=0.0940	coverage=0.0733
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.1466	recall=0.1056	coverage=0.0473
# 最相似用户为30个
# Evaluation start ...
# precisioin=0.1545	recall=0.1113	coverage=0.0372
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8709
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   余弦
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.1096	recall=0.0789	coverage=0.2388
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.1862	recall=0.1340	coverage=0.1645
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.2025	recall=0.1458	coverage=0.1258
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.2084	recall=0.1500	coverage=0.1083
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.2166	recall=0.1560	coverage=0.0699
# 最相似用户为30个
# Evaluation start ...
# precisioin=0.2213	recall=0.1593	coverage=0.0568
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8709
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   皮尔逊
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.0196	recall=0.0141	coverage=0.1118
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.0332	recall=0.0239	coverage=0.1564
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.0331	recall=0.0238	coverage=0.1693
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.0285	recall=0.0205	coverage=0.1744
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.0184	recall=0.0133	coverage=0.1786
# 最相似用户为30个
# Evaluation start ...
# precisioin=0.0140	recall=0.0101	coverage=0.1660

# %%
import random
from math import *
from operator import itemgetter
import numpy as np

# 读文件得到“用户-电影”数据
def get_dataset(filename, pivot=0.75):
    trainSet_len = 0
    testSet_len = 0
    
    trainSet = {}
    testSet = {}
    m_dic = {}
    
    for line in load_file(filename):
        user, movie, rating,timestamp  = line.split(',')
        if random.random() < pivot:
            trainSet.setdefault(user, {})
            trainSet[user][movie] = rating
            trainSet_len += 1
            m_dic.setdefault(movie,[])
            m_dic[movie].append(float(rating))
        else:
            testSet.setdefault(user, {})
            testSet[user][movie] = rating
            testSet_len += 1
            m_dic.setdefault(movie,[])
            m_dic[movie].append(float(rating))
    print('Split trainingSet and testSet success!')
    print('TrainSet = %s' % trainSet_len)
    print('TestSet = %s' % testSet_len)
    
    return trainSet, testSet, m_dic


# 读文件，返回文件的每一行
def load_file(filename):
    with open(filename, 'r') as f:
        for i, line in enumerate(f):
            if i == 0:  # 去掉文件第一行的title
                continue
            yield line.strip('\r\n')
    print('Load %s success!' % filename)


def getab(dic_u, dic_v):
    sim_movie = list(dic_u.keys()&dic_v.keys())
    a = []
    b = []
    for m in sim_movie:
        a.append(float(dic_u[m]))
        b.append(float(dic_v[m]))
    
    for k,v in dic_u.items():
        if k not in sim_movie:
            a.append(float(v))
            b.append(0)
    
    for k,v in dic_v.items():
        if k not in sim_movie:
            a.append(0)
            b.append(float(v))

    return a,b

def get_adj_ab(dic_u, dic_v, m_dic):
    sim_movie = list(dic_u.keys()&dic_v.keys())
    a = []
    b = []
    for m in sim_movie:
        num = sum(m_dic[m])/len(m_dic[m])
        a.append(float(dic_u[m])-num)
        b.append(float(dic_v[m])-num)
    
    for k,v in dic_u.items():
        if k not in sim_movie:
            num = sum(m_dic[k])/len(m_dic[k])
            a.append(float(v)-num)
            b.append(-num)
    
    for k,v in dic_v.items():
        if k not in sim_movie:
            num = sum(m_dic[k])/len(m_dic[k])
            a.append(-num)
            b.append(float(v)-num)
    return a,b

def eculidSim(x,y):
    return sqrt(sum(pow(a-b,2) for a,b in zip(x,y)))

def manhattan_dis(x,y):
    return sum(abs(a-b) for a,b in zip(x,y))

def cos_sim(x, y):

    x = np.mat(x)
    y = np.mat(y)
    num = float(x * y.T)
    denom = np.linalg.norm(x) * np.linalg.norm(y)
    sim = num / denom
    return sim

def jaccard_sim(x,y):
    intersection_cardonality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardonality/float(union_cardinality)

# def pearson(vb,vc):
#     return np.mean(np.multiply((vc-np.mean(vc)),(vb-np.mean(vb))))/(np.std(vb)*np.std(vc))

def multipl(a,b):
    sumofab=0.0
    for i in range(len(a)):
        temp=a[i]*b[i]
        sumofab+=temp
    return sumofab
 
def pearson(x,y):
    n=len(x)
    #求和
    sum1=sum(x)
    sum2=sum(y)
    #求乘积之和
    sumofxy=multipl(x,y)
    #求平方和
    sumofx2 = sum([pow(i,2) for i in x])
    sumofy2 = sum([pow(j,2) for j in y])
    num=sumofxy-(float(sum1)*float(sum2)/n)
    #计算皮尔逊相关系数
    den=sqrt((sumofx2-float(sum1**2)/n)*(sumofy2-float(sum2**2)/n))
    return num/den


# 计算用户之间的相似度
def calc_user_sim(trainSet, method, m_dic):
    # 构建“电影-用户”倒排索引
    # key = movieID, value = list of userIDs who have seen this movie
    print('Building movie-user table ...')
    movie_user = {}
    
    user_sim_matrix = {}
    movie_count = 0
    
    for user, movies in trainSet.items():
        for movie in movies:
            if movie not in movie_user:
                movie_user[movie] = set()
            movie_user[movie].add(user)
    print('Build movie-user table success!')

    movie_count = len(movie_user)
    print('Total movie number = %d' % movie_count)

    print('Build user co-rated movies matrix ...')
    for movie, users in movie_user.items():
        for u in users:
            for v in users:
                if u == v:
                    continue
                user_sim_matrix.setdefault(u, {})
                user_sim_matrix[u].setdefault(v, 0)
                user_sim_matrix[u][v] += 1
    print('Build user co-rated movies matrix success!')


    if method == 'sim':
        ######      最基本的那种
        # 计算相似性
        print('Calculating user similarity matrix ...   原始方法')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                user_sim_matrix[u][v] = count / sqrt(len(trainSet[u]) * len(trainSet[v]))
        print('Calculate user similarity matrix success!')
        ######

    if method == 'eculidSim':
        ######  欧几里得距离
        print('Calculating user similarity matrix ...   欧几里得')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = getab(trainSet[u],trainSet[v])
                    user_sim_matrix[u][v] = eculidSim(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')
        ######
    
    if method == 'manhattan':
        print('Calculating user similarity matrix ...   曼哈顿')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = getab(trainSet[u],trainSet[v])
                    user_sim_matrix[u][v] = manhattan_dis(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')

    if method == 'jaccard':
        print('Calculating user similarity matrix ...   jaccard')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = getab(trainSet[u],trainSet[v])
                    user_sim_matrix[u][v] = jaccard_sim(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')

    if method == 'cosine':
        print('Calculating user similarity matrix ...   余弦')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = getab(trainSet[u],trainSet[v])
                    user_sim_matrix[u][v] = cos_sim(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')


    if method == 'pearson':
        print('Calculating user similarity matrix ...   皮尔逊')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = getab(trainSet[u],trainSet[v])
                    user_sim_matrix[u][v] = pearson(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')
    
    if method == 'adj_cosine':
        print('Calculating user similarity matrix ...   改进余弦')
        for u, related_users in user_sim_matrix.items():
            for v, count in related_users.items():
                if count!= 0:
                    a,b = get_adj_ab(trainSet[u],trainSet[v], m_dic)
                    user_sim_matrix[u][v] = cos_sim(a,b)
                else:
                    user_sim_matrix[u][v] = 0
        print('Calculate user similarity matrix success!')
    
    return user_sim_matrix, movie_count


# 针对目标用户U，找到其最相似的K个用户，产生N个推荐
def recommend(user, n_sim_user, n_rec_movie, trainSet, user_sim_matrix, m_dic):
    K = n_sim_user
    N = n_rec_movie
    rank = {}
    watched_movies = trainSet[user]

    # v=similar user, wuv=similar factor
    # print(user)
    xxx = sorted(user_sim_matrix[user].items(), key=itemgetter(1), reverse=True)[0:K]
    for v, wuv in xxx:
        for movie,value in trainSet[v].items():
            if movie in watched_movies:
                continue
            rank.setdefault(movie, 0)
            aaa = 0
            if v in m_dic:
                aaa = (sum(m_dic[v])/len(m_dic[v]))
            rank[movie] += wuv*(float(value)-aaa)
    return sorted(rank.items(), key=itemgetter(1), reverse=True)[0:N]


# 产生推荐并通过准确率、召回率和覆盖率进行评估
def evaluate(n_rec_movie, trainSet, user_sim_matrix, testSet, n_sim_user, movie_count, m_dic):
    print("Evaluation start ...")
    N = n_rec_movie
    # 准确率和召回率
    hit = 0
    rec_count = 0
    test_count = 0
    # 覆盖率
    all_rec_movies = set()

    for i, user, in enumerate(trainSet):
        if user in user_sim_matrix:
            test_movies = testSet.get(user, {})
            rec_movies = recommend(user, n_sim_user, n_rec_movie, trainSet, user_sim_matrix,m_dic)
            for movie, w in rec_movies:
                if movie in test_movies:
                    hit += 1
                all_rec_movies.add(movie)
            rec_count += N
            test_count += len(test_movies)

    precision = hit / (1.0 * rec_count)
    recall = hit / (1.0 * test_count)
    coverage = len(all_rec_movies) / (1.0 * movie_count)
    print('precisioin=%.4f\trecall=%.4f\tcoverage=%.4f' % (precision, recall, coverage))


# trainSet, testSet = get_dataset(filename = 'ml/rating.csv', pivot=1)
# user_sim_matrix, movie_count = calc_user_sim(trainSet)
# n_sim_user = 10
# n_rec_movie = 20

trainSet, testSet, m_dic = get_dataset(filename = 'ratings.csv')
methods = ['sim', 'eculidSim', 'manhattan', 'jaccard', 'cosine', 'pearson']
for method in methods:
    user_sim_matrix, movie_count = calc_user_sim(trainSet, method, m_dic)
    for num in [1,5,8,10,20]: 
        n_sim_user = num
        n_rec_movie = 30
        print('最相似用户为{}个'.format(num))
        evaluate(n_rec_movie, trainSet, user_sim_matrix, testSet, n_sim_user, movie_count, m_dic)
# Out:
# Load ratings.csv success!
# Split trainingSet and testSet success!
# TrainSet = 75603
# TestSet = 25233
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8816
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   原始方法
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.1099	recall=0.0797	coverage=0.2216
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.1552	recall=0.1126	coverage=0.1866
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.1662	recall=0.1205	coverage=0.1525
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.1696	recall=0.1230	coverage=0.1374
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.1857	recall=0.1347	coverage=0.0929
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8816
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   欧几里得
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.0575	recall=0.0417	coverage=0.0134
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.0677	recall=0.0491	coverage=0.0217
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.0746	recall=0.0541	coverage=0.0212
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.0740	recall=0.0537	coverage=0.0203
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.0918	recall=0.0666	coverage=0.0186
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8816
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   曼哈顿
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.0574	recall=0.0416	coverage=0.0123
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.0721	recall=0.0523	coverage=0.0169
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.0780	recall=0.0566	coverage=0.0205
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.0770	recall=0.0558	coverage=0.0192
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.0899	recall=0.0652	coverage=0.0172
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8816
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   jaccard
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.0666	recall=0.0483	coverage=0.1892
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.0895	recall=0.0649	coverage=0.1380
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.1022	recall=0.0741	coverage=0.1175
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.1049	recall=0.0761	coverage=0.1037
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.1242	recall=0.0900	coverage=0.0725
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8816
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   余弦
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.1108	recall=0.0803	coverage=0.2307
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.1551	recall=0.1125	coverage=0.1922
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.1670	recall=0.1211	coverage=0.1585
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.1715	recall=0.1244	coverage=0.1402
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.1869	recall=0.1356	coverage=0.0934
# Building movie-user table ...
# Build movie-user table success!
# Total movie number = 8816
# Build user co-rated movies matrix ...
# Build user co-rated movies matrix success!
# Calculating user similarity matrix ...   皮尔逊
# Calculate user similarity matrix success!
# 最相似用户为1个
# Evaluation start ...
# precisioin=0.0202	recall=0.0146	coverage=0.0964
# 最相似用户为5个
# Evaluation start ...
# precisioin=0.0365	recall=0.0265	coverage=0.1483
# 最相似用户为8个
# Evaluation start ...
# precisioin=0.0366	recall=0.0265	coverage=0.1445
# 最相似用户为10个
# Evaluation start ...
# precisioin=0.0354	recall=0.0256	coverage=0.1351
# 最相似用户为20个
# Evaluation start ...
# precisioin=0.0252	recall=0.0183	coverage=0.1191
